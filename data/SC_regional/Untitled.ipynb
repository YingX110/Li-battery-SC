# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('new_EF_SC.csv')
country = df['country'].tolist()
len(country)
# Out:
# 29

# %%
emisink = pd.read_csv('emission_sink.csv', index_col=0)
emisinknew = emisink.loc[country, :]

# %%
emisinknew.to_csv('emission_sinknew.csv', index=True)

# %%
capacity = pd.read_csv('capacity.csv', index_col=0)
capacitynew = capacity.loc[country, :]
capacitynew.to_csv('capacitynew.csv', index=True)

# %%
dis = pd.read_csv('distance.csv', index_col=0)
dis
# Out:
#                          Argentina     Australia       Bahrain       Bolivia  \
# Argentina                 0.000000  12704.805950  13804.129660   2460.297528
# Australia             12704.805950      0.000000  10592.456840  15025.296590
# Bahrain               13804.129660  10592.456840      0.000000  13167.963770
# Bolivia                2460.297528  15025.296590  13167.963770      0.000000
# Brazil                 2924.249906  15578.635140  11923.756040   1271.636811
# Canada                11259.052370  14151.639510  10617.831480   8984.713171
# Chile                   766.299080  12734.137910  14465.753000   2295.174766
# China                 18898.993960   7474.364746   5164.490456  17525.418380
# Colombia               4905.061758  16238.335020  13173.435030   2601.494692
# Congo                  9325.988070  12002.782270   4563.179272   9385.909957
# Cuba                   6826.747695  16775.259220  12334.432910   4480.130608
# ...
